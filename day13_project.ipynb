# %%
# Day 13 - Student Score Prediction

import pandas as pd
from sklearn.linear_model import LinearRegression

# Load dataset
data = pd.read_csv("student_scores.csv")

# Display dataset
print(data)

# Prepare training data
X = data[["Study_Hours"]]
y = data["Score"]

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Predict score for 6 study hours
prediction = model.predict([[6]])

print("Predicted Score:", round(prediction[0], 2))
# Out:
#    Study_Hours  Score
# 0            1     35
# 1            2     40
# 2            3     50
# 3            4     55
# 4            5     60
# 5            6     70
# 6            7     75
# 7            8     85
# Predicted Score: 69.29
# c:\Users\rajan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
